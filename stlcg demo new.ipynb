# %%
# %matplotlib inline
import sys
sys.path.insert(0, 'src')

# %%
import stlcg
import stlviz as viz
from stlcg import Expression
from utils import print_learning_progress

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import importlib

# %% [markdown]
# ## Create traces from numpy arrays

# %%
t = t = np.arange(-3, 3, 0.2, dtype=np.float32)
x_np = 0.5 * np.exp(-t**2).reshape([1, t.shape[0], 1])
w_np = (0.4*np.exp(-(t + 0.5)**2) + 0.2*np.exp(-(t - 3)**2)).reshape([1, t.shape[0], 1])

x = torch.tensor(x_np, requires_grad=False)
w = torch.tensor(w_np, requires_grad=False)
c = torch.tensor(1.0, dtype=torch.float, requires_grad=True)
d = torch.tensor(0.9, dtype=torch.float, requires_grad=True)

# %%
plt.figure(figsize=(8, 5))
plt.plot(t, x_np[0,:,0], ".-", linewidth=3, markersize=15, label="x")
plt.plot(t, w_np[0,:,0], ".-", linewidth=3, markersize=15, label="w")
plt.legend(fontsize=16)
plt.title("Traces", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Traces')

# %% [markdown]
# # Constructing STL formulas

# %% [markdown]
# ### One way to construct formulas is to explicitly call the constructors

# %%
ϕ1 = stlcg.LessThan(name='x', val=c)
ϕ2 = stlcg.GreaterThan(name='w', val=d)
ϕ3 = stlcg.LessThan(name='w', val=d)
ϕ = stlcg.Always(subformula=ϕ1)
ψ = stlcg.Always(subformula=ϕ3)
formula = stlcg.And(subformula1=ϕ, subformula2=ψ)
print(formula)
viz.make_stl_graph(formula)
# Out:
# (◻ [0, inf]( x <= 1.0 )) ∧ (◻ [0, inf]( w <= 0.9 ))

# %% [markdown]
# ### Another way (preferred way) is to use the math operators which have been overloaded
# #### (less than, greater than, equal, not, and, or)
# #### Still need to use the Always and Or constructors explicitly

# %%
x_exp = Expression('x', x)    # The first argument is the name of the variable, the second argument is the numerical value
w_exp = Expression('w', w)
c_exp = Expression(c)         # If the variable is a parameter of the STL, then input the actual value
d_exp = Expression(d)

# %%
ϕ1 = x_exp <= c_exp
ϕ2 = w_exp >= d_exp 
ϕ3 = w_exp <= d_exp
ϕ = stlcg.Always(subformula=ϕ1)
ψ = stlcg.Always(subformula=ϕ3)
formula = stlcg.And(subformula1=ϕ, subformula2=ψ)
print(formula)
viz.make_stl_graph(formula)
# Out:
# (◻ [0, inf]( x <= 1.0 )) ∧ (◻ [0, inf]( w <= 0.9 ))

# %% [markdown]
# ## Evaluating the formula
# ### You need to feed in the necessary inputs. If the formula requires multiple inputs, it takes in a tuple of length 2 where each element in the tuple is the input to each subformula, in the order they are created. If the formula requires more than two inputs, then the tuple contains a tuple, eg. (x, (y, z)). The grouping of the input traces depend on how the formula was created.
#
# #### the inputs can be made up of tensors, or Expression objects.

# %%
formula2 = ϕ2 & formula
print(formula2)
viz.make_stl_graph(formula2)
# Out:
# (w >= 0.9) ∨ ((◻ [0, inf]( x <= 1.0 )) ∧ (◻ [0, inf]( w <= 0.9 )))

# %%
# any of the inputs will work
inputs = (w, (x_exp, w_exp))
# inputs = (w_exp, (x_exp, w_exp))
# inputs = (w, (x, w))

pscale = 1     # "pscale" is the scale used for evaluting predicates
scale = -1     # "scale" is the scale used in the maxish/minish function. <0 defaults to the true min/max
formula2(inputs, pscale=pscale, scale=scale);

# %% [markdown]
# # Testing grad functionality

# %%
x_exp = Expression('x', x)
w_exp = Expression('w', w)
c_exp = Expression(c)
d_exp = Expression(d)
lt = x_exp <= c_exp
gt = w_exp <= d_exp
formula = stlcg.Always(subformula=lt)
inputs = x
var_dict = {'c': c}
print(formula)
viz.make_stl_graph(formula)
# Out:
# ◻ [0, inf]( x <= 1.0 )

# %%
learning_rate = 0.05
device = torch.device("cpu")
optimizer = torch.optim.Adam(var_dict.values(), lr=learning_rate)
scale = 0.5

# %%
for i in range(20000):
    sc = scale + i/500
    loss = formula.robustness(inputs, scale=sc).mean()**2 #+ 0.001*(c**2 + d**2)
    if i % 500 == 0:
        print_learning_progress(formula, inputs, var_dict, i, loss, sc)
    loss.backward()
    with torch.no_grad():
        c -= learning_rate * c.grad
        c.grad.zero_()
#         d -= learning_rate * d.grad
#         d.grad.zero_()
# Out:
# iteration: 0 -- loss: 0.995 ---- c:1.000 ---- scale:0.500 ---- true value:0.500
# iteration: 500 -- loss: 0.000 ---- c:0.003 ---- scale:1.500 ---- true value:-0.497
# iteration: 1000 -- loss: 0.000 ---- c:0.003 ---- scale:2.500 ---- true value:-0.497
# iteration: 1500 -- loss: 0.000 ---- c:0.004 ---- scale:3.500 ---- true value:-0.496
# iteration: 2000 -- loss: 0.000 ---- c:0.006 ---- scale:4.500 ---- true value:-0.494
# iteration: 2500 -- loss: 0.000 ---- c:0.009 ---- scale:5.500 ---- true value:-0.491
# iteration: 3000 -- loss: 0.000 ---- c:0.018 ---- scale:6.500 ---- true value:-0.482
# iteration: 3500 -- loss: 0.000 ---- c:0.045 ---- scale:7.500 ---- true value:-0.455
# iteration: 4000 -- loss: 0.000 ---- c:0.114 ---- scale:8.500 ---- true value:-0.386
# iteration: 4500 -- loss: 0.000 ---- c:0.212 ---- scale:9.500 ---- true value:-0.288
# iteration: 5000 -- loss: 0.000 ---- c:0.292 ---- scale:10.500 ---- true value:-0.208
# iteration: 5500 -- loss: 0.000 ---- c:0.344 ---- scale:11.500 ---- true value:-0.156
# iteration: 6000 -- loss: 0.000 ---- c:0.378 ---- scale:12.500 ---- true value:-0.122
# iteration: 6500 -- loss: 0.000 ---- c:0.400 ---- scale:13.500 ---- true value:-0.100
# iteration: 7000 -- loss: 0.000 ---- c:0.416 ---- scale:14.500 ---- true value:-0.084
# iteration: 7500 -- loss: 0.000 ---- c:0.428 ---- scale:15.500 ---- true value:-0.072
# iteration: 8000 -- loss: 0.000 ---- c:0.437 ---- scale:16.500 ---- true value:-0.063
# iteration: 8500 -- loss: 0.000 ---- c:0.443 ---- scale:17.500 ---- true value:-0.057
# iteration: 9000 -- loss: 0.000 ---- c:0.449 ---- scale:18.500 ---- true value:-0.051
# iteration: 9500 -- loss: 0.000 ---- c:0.453 ---- scale:19.500 ---- true value:-0.047
# iteration: 10000 -- loss: 0.000 ---- c:0.457 ---- scale:20.500 ---- true value:-0.043
# iteration: 10500 -- loss: 0.000 ---- c:0.460 ---- scale:21.500 ---- true value:-0.040
# iteration: 11000 -- loss: 0.000 ---- c:0.463 ---- scale:22.500 ---- true value:-0.037
# iteration: 11500 -- loss: 0.000 ---- c:0.465 ---- scale:23.500 ---- true value:-0.035
# iteration: 12000 -- loss: 0.000 ---- c:0.467 ---- scale:24.500 ---- true value:-0.033
# iteration: 12500 -- loss: 0.000 ---- c:0.469 ---- scale:25.500 ---- true value:-0.031
# iteration: 13000 -- loss: 0.000 ---- c:0.471 ---- scale:26.500 ---- true value:-0.029
# iteration: 13500 -- loss: 0.000 ---- c:0.472 ---- scale:27.500 ---- true value:-0.028
# iteration: 14000 -- loss: 0.000 ---- c:0.474 ---- scale:28.500 ---- true value:-0.026
# iteration: 14500 -- loss: 0.000 ---- c:0.475 ---- scale:29.500 ---- true value:-0.025
# iteration: 15000 -- loss: 0.000 ---- c:0.476 ---- scale:30.500 ---- true value:-0.024
# iteration: 15500 -- loss: 0.000 ---- c:0.477 ---- scale:31.500 ---- true value:-0.023
# iteration: 16000 -- loss: 0.000 ---- c:0.478 ---- scale:32.500 ---- true value:-0.022
# iteration: 16500 -- loss: 0.000 ---- c:0.479 ---- scale:33.500 ---- true value:-0.021
# iteration: 17000 -- loss: 0.000 ---- c:0.480 ---- scale:34.500 ---- true value:-0.020
# iteration: 17500 -- loss: 0.000 ---- c:0.480 ---- scale:35.500 ---- true value:-0.020
# iteration: 18000 -- loss: 0.000 ---- c:0.481 ---- scale:36.500 ---- true value:-0.019
# iteration: 18500 -- loss: 0.000 ---- c:0.482 ---- scale:37.500 ---- true value:-0.018
# iteration: 19000 -- loss: 0.000 ---- c:0.482 ---- scale:38.500 ---- true value:-0.018
# iteration: 19500 -- loss: 0.000 ---- c:0.483 ---- scale:39.500 ---- true value:-0.017
